# %%
import numpy as np

def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %%
from keras.applications import inception_v3
from keras import backend as K

K.set_learning_phase(0)

model = inception_v3.InceptionV3(weights='imagenet',
                                 include_top=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 0s 0us/step

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %%
maxlen = 60
step = 3

sentences = []

next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# <ipython-input-10-57764e407abd>:19: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# <ipython-input-10-57764e407abd>:20: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/rmsprop.py:143: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 285s 180ms/step - loss: 1.9744
# --- Generating with seed: "its
# ultimate conclusion knows another loathing unknown to th"
# ------ temperature: 0.2
# its
# ultimate conclusion knows another loathing unknown to the faction of the seem the fact and the more a more a sourse of the concernation of the soul he is the serves and the feel the concernines and the discourse in the concernation of the sere and the deen the most so distours and the most the more a more a sould the concernation of the self-the sense of the concerains and the feel the self a more of the self-the man the soul has a sourse and the been ------ temperature: 0.5
# more of the self-the man the soul has a sourse and the been it is not the existence, of the more something the faction. and it is not the grought
# the masther
# a some hard
# soul, the whole has every his that has existents and lattic possess.--in this noble a nother in the roses and the sense of the such a should the been a nother the comes be individual,
# the self-sourse for the condisint and will dassess of the whole of the heart intolity to the would as i ma------ temperature: 1.0
# sess of the whole of the heart intolity to the would as i man ourwe; he i resposinted frow senous be a thats,"--besmelind
# at the
# asserate povereven the ampensined: morliwrs, hums-proud,--the beevel the eures intulled asmequent neigher.sed possible the feotteized. thue there is togoes the gared. a tran
# individual himself for houre. a con how, the
# comporate thope of
# pores
# yead
# and their oulweret.
#
# kndal, lose which he sulfce and "e) a difference his here tou------ temperature: 1.2
# ndal, lose which he sulfce and "e) a difference his here touus, noble idan
# of our nationve. -as a tarkion
# the octives and
# in oth it is
# "light
# to pebsosce of the good a bvemet distitlual mistruegpatic do so sube another oridinullestapour operts. leats, bet phighilo"fic "s tehe anbenermunbly conilonk more be up ascoppers.--one oun ons, about he opight ims! yow account and reminigival8 of course, art physess infuned
# hard, hereregations adevertawewernds) one repoch 2
# 1565/1565 [==============================] - 270s 173ms/step - loss: 1.6129
# --- Generating with seed: "rm: for with it, in the present state
# of knowledge, one can "
# ------ temperature: 0.2
# rm: for with it, in the present state
# of knowledge, one can be any discovers of the same the discoure which the there is not the desires of the moral past of the same the conduct of the soul and the god the conscious and soul and the same the desire the decerver and the discoure and the desire the good and contrary the there is a moral the sense of the soul and the soul and the be more and the decessition to be any one has be according the really be develo------ temperature: 0.5
# essition to be any one has be according the really be develous "poor that much according the of an roting man
# indeed of the consciously it we conscious spirit who the good with the souls every the personal invelus moral profounder, and the simply in schounde of this indeed, becomes, the the same discoure the and vicis--believe in some was world the sense
# have good there is now the soul has be anatise has a the possible the sinerver, and in the same parting------ temperature: 1.0
# ise has a the possible the sinerver, and in the same parting.
#
#
# 1)
#
# =prepain of the moral, nature,
# their dimateciss, we conducty,--but heapt, the germany of any only
# being lad too less be be right"? may aways of manicanamiaion, mereln bothing placal brought, berows rements dome: in no making happens tremed a  are  laveroy-consmates this
# mises these intenpervence, him as fomequal herith. im the outhinate sending there by at bele the heress
# and deel" in real------ temperature: 1.2
# hinate sending there by at bele the heress
# and deel" in realcy. in axmaght
# most fogriws and regruisting theirr, who is
# at woeknis goods.=--havoetimes of
# timiders.
# notaga4le and desire, it be bigsrist
# alsoe,
# afligin. we perctiops to very decesse, howeit deptadmect these, ptever.
#
# nivoues one his have hos forcnatly, in right,
# "this .for posincisant pook,--he lik musitial of
# experience. the may:eupit of ve truequally" which cersuity--are?"--soun, were-reasoepoch 3
# 1565/1565 [==============================] - 271s 173ms/step - loss: 1.5248
# --- Generating with seed: "ght out of germany. but how could the german language, even
# "
# ------ temperature: 0.2
# ght out of germany. but how could the german language, even
# the sense of the stranger the more have the same the soul and the suppose the artist of the soul and the condition of the deceived and the soul and the sense of the sense of the word of the same the condition of the strengther the soul as a most such and the same and period of the sense of the supposes the strength and the states and period of the same the subject and the strength and the more the------ temperature: 0.5
# od of the same the subject and the strength and the more the artist of the sourses to do the through the good can not it is conduces of a possibiose in the
# nature the wastanced of his words and there is religious moral the suppose and fundamental condited, in the religious the
# word, as self-contentation to have be of the good and
# whether the sension the slave as the everything in the cleasing the idea of the presentary the state of the desire of
# the evils ------ temperature: 1.0
# idea of the presentary the state of the desire of
# the evils of christial bedies" bothing
# want. and the being to himselfgesly one
# awawther which so the strengthest, there is new certain against dun endayory diesporeness the west goim which marty
# of other ; pravudcial judges of usmenty--and this
# mystery. it was
# reacher that the more which the postartions hacce which owes it is
# powerfulne de"s
#
# tordanially
# sentiming mayt copprait wantly
# what others into badom------ temperature: 1.2
# nially
# sentiming mayt copprait wantly
# what others into badomatovary and takes
# animsaly) and tence distrachedjush it oig origiosory; ithiss
# sectuinging quat
# do, one fill szeastfulne so one than he soch giver dupidials, ohersalows oraches. within felle). for all -it ont refirency to valtayys.--this owes be the notionalifice of moral
# takes are "with a prifiaries, earcquoiing to houcomis, ather of the desiraby,
# pregrd, marica spointedness
# be delightfianoty,--fepoch 4
# 1565/1565 [==============================] - 269s 172ms/step - loss: 1.4765
# --- Generating with seed: "r his motives and finally for
# his nature. now, at last, is i"
# ------ temperature: 0.2
# r his motives and finally for
# his nature. now, at last, is its own subjects and the considery to the same time to the same time to the sense of the sentiment of the same the soul and false of the end and the sentiment of the sentiment of the sentiment of the subject of the false and the subject to the subject of the most disclase the sentiment of the man and precisely to the sense of the same the man is the sentiment of the subject of the sentiment of the ------ temperature: 0.5
# man is the sentiment of the subject of the sentiment of the disciplience of mankind the end and such and to god with sentiment with the mankind to religions in the sentiment and interpretation and bad and heart as all our even sentiment of the end emything to them at the super-inded to the soul and precisely to the concempined. but it is a strang in the power in the gree so and with its finer which is not same all the will respect for the interpretation of------ temperature: 1.0
# h is not same all the will respect for the interpretation of virtuate turn
# longwion
# or disci2lent with. on their commond, in kornes with the nevertakence of his heretinary; are
# the man ho
# "seated new truth
# your perfaction
# in what ye inditions and panies intey, with !" everal
# sutpentute in the
# rame as have sent--lought orpponed individual connect only age
# opinion, nasually who also unewlethened from occasions penousing and fasu and volus in
# too will into th------ temperature: 1.2
# m occasions penousing and fasu and volus in
# too will into the with ow do madker glagesul sove imically done who all gow point to frollor finer atsmen!; dutism
# on thooy to utille; a, eby to broughtwarver a full other to thewesine a is a god pridits are will there consignies! abittly ple's one always goodlys at an
# i. feeling!
# the wecally.--the
# kind, else that can: onge over the siekickostal,"
# througtatuls, indeed than is voxitary tiden. somethistenifivened cepoch 5
# 1565/1565 [==============================] - 273s 174ms/step - loss: 1.4469
# --- Generating with seed: "always
# been--the great things remain for the great, the abys"
# ------ temperature: 0.2
# always
# been--the great things remain for the great, the abys and the same the same time the spirit of the same thing and the spirit and an and indiess of the same thinkess of the superfal should be a delights and self-prical there is a standing the superfalsing and an assiminary and stronger the spirit of the same the such a souls the such a man is the same the spirit of the sense and are the same the spirit and the sense of the superfal and all the spirit------ temperature: 0.5
#  the spirit and the sense of the superfal and all the spirit of their himself the sense and more promises of the taste of the same thing of the superfachion and generated morality when the all the science of the histical extent of himany stall in the far and the science we all such a thought to the present the extent of the distinction experience, to the a strong any man to superfal in the devolops the disposited to the fear, and belonges and all prosed an------ temperature: 1.0
# s the disposited to the fear, and belonges and all prosed and foblow and
# overposing to heak one li think, before differing becomes, for
# himy and aded a thinke? who meanschord, youselvess
# alastrial out
# in thonge clevised and alisess, they "spoce of down would, anyonarred from periods evil frueculation
# senses to the spirit for ovest youd metevily. all one
# stafented whom, and withbrt-toldref, as was the bater, and him of yle case of uninally at a tay sirce."------- temperature: 1.2
# the bater, and him of yle case of uninally at a tay sirce."--gee, the dicstoment, alvo, beroundsly secoss, ey iiveuntaness srome bapons: dream anterquell-theiregentiquted--free, dy po expeduenient sy,ne
# deapopperhapons""d, but chilt care friend of this  bhin consider, little es"cood in numberly decises we det by one is nothing liuns overquestional young moral great contapriby outupsiti sort for
# hebe welarted fr aid). such aller the lossf soul soul
# more morepoch 6
# 1565/1565 [==============================] - 273s 174ms/step - loss: 1.4249
# --- Generating with seed: "even severe
# words. he will say: "there is something cruel in"
# ------ temperature: 0.2
# even severe
# words. he will say: "there is something cruel interest in the same the spirit which has not to pat one is all the man, the sense of the spirits, for the spirit to the same taste of the same time the stronger to the same time the same time the state of the possible to be the possess of the possess of the philosophy in the conscience of the superfaching to the fear, the still the spirit of the most conscience of the fact that the spirit of the sp------ temperature: 0.5
# of the most conscience of the fact that the spirit of the spare, to the exceptional of the man. discoverent itself and the sufficient to disknews of the powerfuls, and common to man in the sense of seek the should have so done of those reason of the exhetation and made the life and man,
# every discovered to present of it is all things they are the such something the states, but towards and peoples to the conscience, the discovered in the stander to be at an------ temperature: 1.0
# to the conscience, the discovered in the stander to be at and enzguses on
# gefully disfercant, in conied akint, much findly, of
# any spirit: this preventocation here general, which is rubes and
# moral
# respond adventmes to of the varces ataces of the suthtocturate, and wider, tomater enorgness, in ordinfounder, appear concealed once lovis of has not commands as eye, not sloight, swative man of sougained, the, as a comedings' applaced which this stherst from
# su------ temperature: 1.2
# ed, the, as a comedings' applaced which this stherst from
# sung. igaristive,
# known, the live, to bes, nequal confluence of to law in two every disflextion, have comes rendereds casts
# uponselitual, an
# smi full-mor. wes women strongers--it is put patomon a,  style, englies,
# the botry, and deceive, me
# 8apithone
# power -impleeeds, bloups hitherto not
# werlews dreadival capmotical paths et doo.=--they thing hisport" and
# segrifationate, eppreh.
# minticance the "ex.
# epoch 7
# 1565/1565 [==============================] - 272s 174ms/step - loss: 1.4051
# --- Generating with seed: "es itself. among these is the incidental remark of madame de"
# ------ temperature: 0.2
# es itself. among these is the incidental remark of madame desire to the consist the sense and self the sense of the sense of the suffering the such and the sense of the sense and the sense of the sense of the most proposition of the sense of the most a seriet to the consequent of the sense of the thought and the sense and the sense of the sense of the strong and discoverent of the sense of the sense and the sense of the most consequently the sense the sens------ temperature: 0.5
# se and the sense of the most consequently the sense the sense be !
#
#
# 13
#
# =servest man, the since of the partially the respected
# be way by the for the spirit in the most the done things of the world which it is a sore too love one always something person in the sense and do others and deed the moral requires and sense of its own as a seriets and artion to some tester such and in the said of the or feelings to the fear of the
# strung the
# miss(sor in the profo------ temperature: 1.0
# feelings to the fear of the
# strung the
# miss(sor in the proforce,"--like which
# is attain that such taking in the base exist its pregnding straignt a stais, indeed, it, it may not like as to cause
# evolty it.
#
# 1owny mej, that.
# it, howect, as
# we arour
# thought; so
# becomes, booly feirfffratible which siteg, the expenates are drays:
# the
# absele religiou, as and whom it is most
# "with desurplenth blind to a unotificed to examplatice, who that the same falst that he ------ temperature: 1.2
#  unotificed to examplatice, who that the same falst that he co
# le btesh--unquires would serier only quenty,
# llughch itself indialities naturally parts of consequently son
# it,
# roffyess."
#
#          aculmficing--that the commone and hesict new, itself this
# selfitoners,--maiblest
# knowledge afweares of anything
# for this reverent--which,
# consiguing tooh
# are a)." to wermony accouuted as are year and other hourst, otherish, as there free real, wise. a comp is a loepoch 8
# 1565/1565 [==============================] - 270s 173ms/step - loss: 1.3936
# --- Generating with seed: " long, it now
# proposes in its wantonness and indiscretion to"
# ------ temperature: 0.2
#  long, it now
# proposes in its wantonness and indiscretion to the same as the subtlety of the subjuctive false and the superiority of the subelty of the word the subtlety of the subjuct the fature and such and and such and of the world of the subelty of the end and sublime that a subjuctive consequently the subelity of the subjuct is an a man with the and the sense of the worst and such and such and the word in the subjuctive the subely and of the subjuctiv------ temperature: 0.5
# d the word in the subjuctive the subely and of the subjuctive and exertion of the principal and his respection and such as a same an exception and problem of the acts and
# the sense of such and in the respaited the suffered, in the according to the contemptation of the present
# soul and multic pressings and such and as only the more with the doma human spirit of the will and extents and ground that self-conting, and in the same words of the her will the have------ temperature: 1.0
# self-conting, and in the same words of the her will the have sults that have to made resinting christianity casted clums the same preditations. the asvarons capible first mavooisgs in men.
# supled good domany--to econd empr nessioning and devility from unitional feelings of eble
# with will person is great woedly floed, not do wholly growte knowledge; manifesting which has a second, cavery. .
#
#           ny
# only that yaugh to absardation of the delicate is alc------ temperature: 1.2
#     ny
# only that yaugh to absardation of the delicate is alc impressionly ad us base him, is beelessquele enterce from himself, rueke "master, however--alny
# another, i reselvers in sajugure mean to siguer."
#
#
# in
# unconsigorie,)--sromenhers, have movering-therefore's own religion, abse gjonting ethic sycritions, and
# of thee they said thelening in such as nature  at all, but those would have
# string
# domined, european you advances, our batetic cesteusly, mingalepoch 9
# 1565/1565 [==============================] - 277s 177ms/step - loss: 1.3806
# --- Generating with seed: "atitude, prayer, of truces between enemies, of loans upon se"
# ------ temperature: 0.2
# atitude, prayer, of truces between enemies, of loans upon selfish the solitude. and the saints, and the sense of the same as in the superiority of the same and something and an an and desires of the such and the soul and sole of the soution of the saint and the sense of the same and an an and and even and in the same and sense of the superiority of the sense of the superiorition of the sense of the superiorition of the soul and the soul the soul and the sa------ temperature: 0.5
# e superiorition of the soul and the soul the soul and the saint to raricion and precisely artion and strong modes of the sense which your own and are the emotions: and that there has one is to be whole who are so moral that the roman one must be been and for the san counter perhaps an attack of the superiority of the solitude, and one another as a desires to consideration of the sense of the words of the german unother so evily that which has a suffered an------ temperature: 1.0
#  of the german unother so evily that which has a suffered an moreibling inclusen
# and conscionish: the prabseristions are, "we. convienes.--it i way, in its one is not as
# the too as it all , in
# pointion to sone in thie even that such astunge as
# these dispurior
# of died yet one has inclies-truth,hat society, the agreence must be nothiness and words of this dbet--e, the implaced
# and their aristious name, if, all this reason would not
# sought of indmin and anyno------ temperature: 1.2
# me, if, all this reason would not
# sought of indmin and anynotic formxcabless. countlated entire
# oblike, wherleatiscomm an orrumive. to
# re precessing prological shirt sunwired, "intellempe and all munilectic,--so so as piour, into the wayfus, influen, actest or other
# we! to acccaces to his laves of noim ot
# one a dedignt of from "grew in or and
# let us besicion call her devid of forr himself is bothing
# sad other
# leve mutical
# "invold or as u., profou is, whichepoch 10
#   48/1565 [..............................] - ETA: 4:31 - loss: 1.3274
